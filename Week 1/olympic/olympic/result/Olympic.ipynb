# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# المپیک</font>
# </h1>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در این تمرین می خواهیم برای مجموعه‌داده‌ی برندگان مدال المپیک از سال ۱۸۹۶ تا ۲۰۱۲ نمودارهایی را رسم کنیم.
# کتابخانه‌ی مجاز برای مصورسازی این تمرین تنها
# <code>matplotlib</code>
# است.
# </font>
# </p>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <b style="color:red">نکته‌ی مهم:</b>
# در این تمرین نیاز است حتماً از نسخه‌ی <code>matplotlib==3.7.1</code> استفاده کنید.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# افزودن کتابخانه‌ها
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#  ابتدا کتابخانه‌های مورد نیازتان را وارد کنید و سپس مجموعه‌داده را از فایل <code>Olympics-Data.csv</code> بخوانید و در متغیر <code>data</code> بریزید.
# </font>
# </p>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('F:\Desktop\DATA SCIENCE BOOTCAMP\olympic\olympic\Olympics-Data.csv')
df = pd.DataFrame(data)

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# نمودار اول: ۱۰ کشور برتر
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     در این نمودار با استفاده از یک نمودار میله‌ای، ۱۰ کشوری که بیشترین مدال <i><b>طلا</b></i> را دریافت کردند رسم کنید.
#     <br>
#     جزئیاتی که باید در نمودار رعایت کنید:
#     <br>
# </font>
# </p>
#
# <center>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# | مقدار | ویژگی |
# | :--: | :--: |
# | <code>(10, 6)</code> | <span dir=rtl>اندازه‌ی نمودار (<code>figsize</code>)</span> |
# | <code dir=ltr>#005f73</code> | رنگ میله‌های نمودار |
# | <code dir=ltr>#EAF4f4</code> | رنگ پس‌زمینه |
# | حذف شوند | <span dir=rtl>محورهای بالا، چپ و راست (به کمک <code>spines</code>)</span> |
# | ۱۰ | <span dir=rtl>اندازه‌ی فونت برچسب محور عمودی (<code>ylabel</code>)</span> |
# | ۱۲ | <span dir=rtl>اندازه‌ی فونت عنوان (<code>title</code>)</span> |
# | <code dir=ltr>length = 0</code> | <span dir=rtl>طول خطوط محورها (<code>tick_params</code>)</span> |
# | ۵۰۰ | گام محور عمودی |
# | ۴۵ | <span dir=rtl>زاویه‌ی متن محور افقی (<code>tick_params</code>)</span> |
# | <code dir=ltr>#22333b</code> | <span dir=rtl>رنگ نوشته‌ها (<code>title</code>، <code>ylabel</code>، <code>tick label</code>)</span> |
# | Top 10 Countries with the Most Gold Medals | <span dir=rtl>عنوان نمودار (<code>title</code>)</span> |
# | Number of Gold Medals |  <span dir=rtl>برچسب محور عمودی (<code>ylabel</code>)</span> |
#
#
# </font>
# </p>
# </center>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# اجزای نمودار حاصل باید کاملاً شبیه به شکل زیر باشد:
# </font>
# </p>
#
# <center>
# <div style="max-width:512px">
# <img src="fig_top10.png" >
# </div>
# </center>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <b style="color:green">نکته‌:</b>
# نمودار را به کمک <code>plt.subplots</code> رسم کنید.
# </font>
# </p>

# %%
gold_counts = df[df['Medal'] == 'Gold']['Country'].value_counts()

top_10_countries = gold_counts.head(10)

fig_top10, ax_top10 = plt.subplots(figsize=(10, 6), facecolor='#EAF4f4')

ax_top10.bar(top_10_countries.index, top_10_countries.values, color='#005f73')

ax_top10.set_ylabel('Number of Gold Medals', color='#22333b', fontsize=10)
ax_top10.set_title('Top 10 Countries with the Most Gold Medals', color='#22333b', fontsize=12)

ax_top10.tick_params(axis='both', length=0)

ax_top10.spines['right'].set_visible(False)
ax_top10.spines['top'].set_visible(False)
ax_top10.spines['left'].set_visible(False)

ax_top10.set_facecolor('#EAF4f4')

ax_top10.tick_params(axis='both', colors='#22333b')
ax_top10.xaxis.set_tick_params(rotation=45)

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# نمودار دوم: تعداد مدال گرفته‌شده در هر سال براساس تفکیک جنسیت
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     در این نمودار تعداد مدال گرفته‌شده در هر سال  به تفکیک جنسیت با استفاده از نمودار خطی نشان دهید.
#     <br>
#     جزئیاتی که باید در نمودار رعایت کنید :
#     <br>
# </font>
# </p>
#
# <center>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# | مقدار | ویژگی |
# | :--: | :--: |
# | <code>(10, 6)</code> | <span dir=rtl>اندازه‌ی نمودار (<code>figsize</code>)</span> |
# | <code dir=ltr>#EAF4f4</code> | رنگ پس‌زمینه |
# | <code dir=ltr>#EAF4f4</code> | <span dir=rtl>رنگ پس‌زمینه <code>legend</code></span> |
# | <code dir=ltr>#005f73</code> | <span dir=rtl>رنگ بخش مردان</span> |
# | <code dir=ltr>#94d2bd </code> | <span dir=rtl>رنگ بخش زنان</span> |
# | <code dir=ltr>#94d2bd</code> | <span dir=rtl>رنگ فاصله‌ی بین خط افقی و نمودار بخش زنان (به کمک <code>fill_between</code>)</span> |
# | ۰.۶ | <span dir=rtl>مقدار <code>alpha</code> برای فاصله‌ی بین خط افقی و نمودار بخش زنان</span> |
# | <code dir=ltr>#005f73</code> | <span dir=rtl>رنگ فاصله‌ی بین نمودار بخش زنان و مردان (به کمک <code>fill_between</code>)</span> |
# | ۰.۶ | <span dir=rtl>مقدار <code>alpha</code> برای فاصله‌ی بین نمودار بخش زنان و مردان</span> |
# | حذف شوند | <span dir=rtl>محورهای بالا، چپ و راست (به کمک <code>spines</code>)</span> |
# | <code dir=ltr>length = 0</code> | <span dir=rtl>طول خطوط محورها (<code>tick_params</code>)</span> |
# | <code dir=ltr>(1896, 2012)</code> | <span dir=rtl>محدوده‌ی محور افقی (<code>xlim</code>)</span> |
# | سمت راست | <span dir=rtl>محل قرارگیری محور عمودی (<code>yaxis</code>)</span> |
# | <code dir=ltr>#22333b</code> | <span dir=rtl>رنگ نوشته‌ها (<code>title</code>، <code>ylabel</code>، <code>tick label</code>)</span> |
# | ۱۰ | <span dir=rtl>اندازه‌ی فونت برچسب محور عمودی (<code>ylabel</code>)</span> |
# | ۱۲ | <span dir=rtl>اندازه‌ی فونت عنوان (<code>title</code>)</span> |
# | Male and Female Won Medals over the Years | <span dir=rtl>عنوان نمودار (<code>title</code>)</span> |
# | Number of Won Medals | <span dir=rtl>برچسب محور عمودی (<code>ylabel</code>)</span> |
#
# </font>
# </p>
# </center>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# اجزای نمودار حاصل باید کاملاً شبیه به شکل زیر باشد:
# </font>
# </p>
#
# <center>
# <div style="max-width:512px">
# <img src="fig_gen.png" >
# </div>
# </center

# %%
medal_counts = df.groupby(['Year', 'Gender']).size().unstack()

fig_gen, ax_gen = plt.subplots(figsize=(10, 6), facecolor='#EAF4f4')

ax_gen.set_facecolor('#EAF4f4')

ax_gen.plot(medal_counts.index, medal_counts['Men'], color='#005f73', label='Men', marker='o')
ax_gen.plot(medal_counts.index, medal_counts['Women'], color='#94d2bd', label='Women', marker='o')

ax_gen.fill_between(medal_counts.index, medal_counts['Men'], medal_counts['Women'], color='#005f73', alpha=0.6)
ax_gen.fill_between(medal_counts.index, 0, medal_counts['Women'], color='#94d2bd', alpha=0.6)

ax_gen.set_ylabel('Number of Won Medals', color='#22333b', fontsize=10)
ax_gen.set_title('Male and Female Won Medals over the Years', color='#22333b', fontsize=12)
ax_gen.tick_params(axis='both', length=0, colors='#22333b')

legend = ax_gen.legend(facecolor='#EAF4f4')


# Set the y-axis on the right side
ax_gen.yaxis.tick_right()

# Set the x-axis limit
ax_gen.set_xlim(1896, 2012)

# Remove the spines
ax_gen.spines['right'].set_visible(False)
ax_gen.spines['top'].set_visible(False)
ax_gen.spines['left'].set_visible(False)

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# نمودار سوم: آنالیز مدال های دریافتی کشور اسلوواکی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     فرض کنید می‌خواهید تعداد مدال های دریافتی در رشته‌های (sport) برای کشور اسلوواکی (<code>SVK</code>) را ببینید
#     ابتدا یک نمودار دوناتی برای رشته‌هایی که مدالی دریافت کرده‌اند را رسم کنید .
#     سپس در داخل آن، نمودار دوناتی دیگری رسم کنید که نشان‌دهنده‌ی تعداد مدال طلا و نقره و برنز در هر رشته هستند
#     <br>
#     جزئیاتی که باید در نمودار رعایت کنید :
#     <br>
# </font>
# </p>
#
#
# <center>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# | مقدار | ویژگی |
# | :--: | :--: |
# | <code>(10, 8)</code> | <span dir=rtl>اندازه‌ی نمودار (<code>figsize</code>)</span> |
# | <code dir=ltr>#EAF4f4</code> | رنگ پس‌زمینه |
# | <code dir=ltr>#EAF4f4</code> | <span dir=rtl>رنگ پس‌زمینه‌ی <code>legend</code></span> |
# | <code dir=ltr>['#d8f3dc', '#b7e4c7', '#95d5b2','#74c69d','#52b788','#40916c']</code> | <span dir=rtl>رنگ <code>wedge</code> های نمودار دوناتی خارجی</span> |
# | <code dir=ltr>{'Gold': '#E9C46A', 'Silver': '#E0E1DD', 'Bronze': '#CD7F32'}</code> | <span dir=rtl>رنگ طلا و نقره و برنز (نمودار داخلی )</span> |
# | ۱ | <span dir=rtl>شعاع (<code>radius</code>) نمودار خارجی</span> |
# | ۰.۷ | <span dir=rtl>شعاع (<code>radius</code>) نمودار داخلی</span> |
# | ۰.۳ | <span dir=rtl>عرض (<code>width</code>) هر دو نمودار</span> |
# | <code dir=ltr>w</code> | <span dir=rtl>رنگ <code>edgecolor</code> هر دو نمودار</span> |
# | ۰.۷۵ | <span dir=rtl>فاصله‌ی برچسب (<code>labeldistance</code>) در نمودار داخلی</span> |
# | <code dir=ltr>#22333b</code> | <span dir=rtl>رنگ نوشته‌ها (<code>title</code>)</span> |
# | ۱۲ | <span dir=rtl>اندازه‌ی فونت عنوان (<code>title</code>)</span> |
# | Count of Medals in each Sport | <span dir=rtl>عنوان نمودار (<code>title</code>)</span> |
#
# </font>
# </p>
# </center>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# اجزای نمودار حاصل باید شبیه به شکل زیر باشد (ترتیب آن اهمیت ندارد):
# </font>
# </p>
#
# <center>
# <div style="max-width:512px">
# <img src="fig_SVK.png" >
# </div>
# </center

# %%
fig_SVK, ax_SVK = plt.subplots(figsize=(10, 8))

"""
# Filter the data for the SVK country
svk_data = df[df['Country'] == 'SVK']

# Count the number of medals in each sport for SVK
medal_counts_sport = svk_data['Sport'].value_counts()

# Create the outer donut chart for sports
fig_SVK, ax_SVK = plt.subplots(figsize=(10, 8))
fig_SVK.patch.set_facecolor('#EAF4F4')

# Set the colors for the sports
outer_colors = ['#D8F3DC', '#B7E4C7', '#95D5B2', '#74C69D', '#52B788', '#40916C']

ax.pie(medal_counts_sport.values, labels=medal_counts_sport.index,
       startangle=90, wedgeprops=dict(width=0.3, edgecolor='#FFFFFF'), colors=outer_colors,
       textprops={'fontsize': 10})

# Create the inner donut chart for gold, silver, and bronze medals within each sport
inner_labels = ['Gold', 'Silver', 'Bronze']
inner_colors = ['#E9C46A', '#C0C0C0', '#CD7F32']

inner_radius = 0.7
width = 0.3

for i, sport in enumerate(medal_counts_sport.index):
    sport_data = svk_data[svk_data['Sport'] == sport]
    medal_counts_type = sport_data['Medal'].value_counts()
    inner_sizes = medal_counts_type.reindex(inner_labels, fill_value=0).values

    inner_ax = plt.gca()
    inner_ax.pie(inner_sizes, colors=inner_colors, radius=inner_radius,
                 startangle=90, wedgeprops=dict(width=width, edgecolor='w'), labels=inner_labels,
                 textprops={'fontsize': 10})

    inner_ax.set(aspect='equal')

    # Set the title for each sport
    inner_ax.set_title(sport, loc='center', color='#22333B', fontsize=12)

    # Add medal names as annotations
    wedges, _ = inner_ax.pie(inner_sizes, colors=inner_colors, radius=inner_radius,
                             startangle=90, wedgeprops=dict(width=width, edgecolor='w'))

    # Add annotations for medal names
    for wedge, label in zip(wedges, inner_labels):
        x, y = wedge.center
        inner_ax.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points',
                          ha='center', va='center', fontsize=10)

    # Add a circle in the middle to separate the sports
    ax.add_artist(plt.Circle((0, 0), inner_radius - width, color='white'))

# Set the title for the outer donut chart
ax.set_title('Count of Medals in each Sport', color='#22333B', fontsize=12)

# Display the chart
plt.show()
"""
# Out:
# "\n# Filter the data for the SVK country\nsvk_data = df[df['Country'] == 'SVK']\n\n# Count the number of medals in each sport for SVK\nmedal_counts_sport = svk_data['Sport'].value_counts()\n\n# Create the outer donut chart for sports\nfig_SVK, ax_SVK = plt.subplots(figsize=(10, 8))\nfig_SVK.patch.set_facecolor('#EAF4F4')\n\n# Set the colors for the sports\nouter_colors = ['#D8F3DC', '#B7E4C7', '#95D5B2', '#74C69D', '#52B788', '#40916C']\n\nax.pie(medal_counts_sport.values, labels=medal_counts_sport.index,\n       startangle=90, wedgeprops=dict(width=0.3, edgecolor='#FFFFFF'), colors=outer_colors,\n       textprops={'fontsize': 10})\n\n# Create the inner donut chart for gold, silver, and bronze medals within each sport\ninner_labels = ['Gold', 'Silver', 'Bronze']\ninner_colors = ['#E9C46A', '#C0C0C0', '#CD7F32']\n\ninner_radius = 0.7\nwidth = 0.3\n\nfor i, sport in enumerate(medal_counts_sport.index):\n    sport_data = svk_data[svk_data['Sport'] == sport]\n    medal_counts_type = spor
# ...

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zlib
import zipfile
import joblib

joblib.dump(fig_gen, "fig_gen")
joblib.dump(fig_top10, "fig_top10")
joblib.dump(fig_SVK, "fig_SVK")

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

file_names = ["fig_gen", "fig_top10", "fig_SVK", "Olympic.ipynb"]
compress(file_names)
# Out:
# File Paths:
# ['fig_gen', 'fig_top10', 'fig_SVK', 'Olympic.ipynb']
